# %%
import os
import xml.etree.ElementTree as ET
import base64
import soundfile as sf
import numpy as np

# %%
# Set input and output paths
input_folder = 'D:/audios'  # Change to your XML folder path
output_folder = 'D:/audioswav'  # Change to your desired WAV output folder
os.makedirs(output_folder, exist_ok=True)

def extract_wav_from_xml(xml_path):
    # Parse the XML file
    tree = ET.parse(xml_path)
    root = tree.getroot()
    
    # Handle namespaces
    ns = {'ns3': 'http://ws.bast.de/container/TrafficDataService'}

    # Extract BASE64 encoded data and filename
    for binary in root.findall('.//ns3:binary', ns):
        file_name = os.path.splitext(os.path.basename(xml_path))[0] + '.wav'
        base64_data = binary.text.strip()

        # Decode BASE64 data
        wav_data = base64.b64decode(base64_data)

        # Check if data starts with 'RIFF' (WAV signature)
        print(f'{file_name} - First 20 bytes: {wav_data[:20]}')
        if not wav_data.startswith(b'RIFF'):
            print(f'Warning: {file_name} does not appear to be a valid WAV file.')
            continue

        # Write to WAV file
        output_path = os.path.join(output_folder, file_name)
        with open(output_path, 'wb') as f:
            f.write(wav_data)
        print(f'Saved: {output_path}')

        # Check audio file using soundfile
        try:
            data, samplerate = sf.read(output_path)
            print(f'File: {file_name}')
            print(f'Sample Rate: {samplerate} Hz')
            print(f'Duration: {len(data) / samplerate:.2f} seconds')
            print(f'Channels: {data.shape[1] if len(data.shape) > 1 else 1}')
        except Exception as e:
            print(f'Error reading {file_name}: {e}')

# Process all XML files in the input folder
for xml_file in os.listdir(input_folder):
    if xml_file.endswith('.xml'):
        extract_wav_from_xml(os.path.join(input_folder, xml_file))

print('Conversion complete!')
# Out:
# 01-FB-Mi1.wav - First 20 bytes: b'RIFF$\xac\x00\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\01-FB-Mi1.wav
# File: 01-FB-Mi1.wav
# Sample Rate: 44100 Hz
# Duration: 0.25 seconds
# Channels: 1
# 01-FB-Mi2.wav - First 20 bytes: b'RIFF$\xac\x00\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\01-FB-Mi2.wav
# File: 01-FB-Mi2.wav
# Sample Rate: 44100 Hz
# Duration: 0.25 seconds
# Channels: 1
# 01-FB-Mi3.wav - First 20 bytes: b'RIFF$\xac\x00\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\01-FB-Mi3.wav
# File: 01-FB-Mi3.wav
# Sample Rate: 44100 Hz
# Duration: 0.25 seconds
# Channels: 1
# 01-FB-Mi4.wav - First 20 bytes: b'RIFF$\xac\x00\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\01-FB-Mi4.wav
# File: 01-FB-Mi4.wav
# Sample Rate: 44100 Hz
# Duration: 0.25 seconds
# Channels: 1
# 01-FB-Mi5.wav - First 20 bytes: b'RIFF$\xac\x00\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\01-FB-Mi5.wav
# File: 01-FB-Mi5.wav
# Sample Rate: 44100 Hz
# Duration: 0.25 seconds
# Channels: 1
# 01-FB-Mi6.wav - First 20 bytes: b'RIFF$\xac\x00\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\01-FB-Mi6.wav
# File: 01-FB-Mi6.wav
# Sample Rate: 44100 Hz
# Duration: 0.25 seconds
# Channels: 1
# 01-FF-Mi1.wav - First 20 bytes: b'RIFF$\x80!\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\01-FF-Mi1.wav
# File: 01-FF-Mi1.wav
# Sample Rate: 44100 Hz
# Duration: 12.45 seconds
# Channels: 1
# 01-FF-Mi2.wav - First 20 bytes: b'RIFF$\x80!\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\01-FF-Mi2.wav
# File: 01-FF-Mi2.wav
# Sample Rate: 44100 Hz
# Duration: 12.45 seconds
# Channels: 1
# 01-FF-Mi3.wav - First 20 bytes: b'RIFF$\x80!\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\01-FF-Mi3.wav
# File: 01-FF-Mi3.wav
# Sample Rate: 44100 Hz
# Duration: 12.45 seconds
# Channels: 1
# 01-FF-Mi4.wav - First 20 bytes: b'RIFF$\x80!\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\01-FF-Mi4.wav
# File: 01-FF-Mi4.wav
# Sample Rate: 44100 Hz
# Duration: 12.45 seconds
# Channels: 1
# 01-FF-Mi5.wav - First 20 bytes: b'RIFF$\x80!\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\01-FF-Mi5.wav
# File: 01-FF-Mi5.wav
# Sample Rate: 44100 Hz
# Duration: 12.45 seconds
# Channels: 1
# 01-FF-Mi6.wav - First 20 bytes: b'RIFF$\x80!\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\01-FF-Mi6.wav
# File: 01-FF-Mi6.wav
# Sample Rate: 44100 Hz
# Duration: 12.45 seconds
# Channels: 1
# 01-H1-Mi1.wav - First 20 bytes: b"RIFF$8'\x00WAVEfmt \x10\x00\x00\x00"
# Saved: D:/audioswav\01-H1-Mi1.wav
# File: 01-H1-Mi1.wav
# Sample Rate: 44100 Hz
# Duration: 14.57 seconds
# Channels: 1
# 01-H1-Mi2.wav - First 20 bytes: b"RIFF$8'\x00WAVEfmt \x10\x00\x00\x00"
# Saved: D:/audioswav\01-H1-Mi2.wav
# File: 01-H1-Mi2.wav
# Sample Rate: 44100 Hz
# Duration: 14.57 seconds
# Channels: 1
# 01-H1-Mi3.wav - First 20 bytes: b"RIFF$8'\x00WAVEfmt \x10\x00\x00\x00"
# Saved: D:/audioswav\01-H1-Mi3.wav
# File: 01-H1-Mi3.wav
# Sample Rate: 44100 Hz
# Duration: 14.57 seconds
# Channels: 1
# 01-H1-Mi4.wav - First 20 bytes: b"RIFF$8'\x00WAVEfmt \x10\x00\x00\x00"
# Saved: D:/audioswav\01-H1-Mi4.wav
# File: 01-H1-Mi4.wav
# Sample Rate: 44100 Hz
# Duration: 14.57 seconds
# Channels: 1
# 01-H1-Mi5.wav - First 20 bytes: b"RIFF$8'\x00WAVEfmt \x10\x00\x00\x00"
# Saved: D:/audioswav\01-H1-Mi5.wav
# File: 01-H1-Mi5.wav
# Sample Rate: 44100 Hz
# Duration: 14.57 seconds
# Channels: 1
# 01-H1-Mi6.wav - First 20 bytes: b"RIFF$8'\x00WAVEfmt \x10\x00\x00\x00"
# Saved: D:/audioswav\01-H1-Mi6.wav
# File: 01-H1-Mi6.wav
# Sample Rate: 44100 Hz
# Duration: 14.57 seconds
# Channels: 1
# 01-H2-Mi1.wav - First 20 bytes: b'RIFF$\x14\x01\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\01-H2-Mi1.wav
# File: 01-H2-Mi1.wav
# Sample Rate: 44100 Hz
# Duration: 0.40 seconds
# Channels: 1
# 01-H2-Mi2.wav - First 20 bytes: b'RIFF$\x14\x01\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\01-H2-Mi2.wav
# File: 01-H2-Mi2.wav
# Sample Rate: 44100 Hz
# Duration: 0.40 seconds
# Channels: 1
# 01-H2-Mi3.wav - First 20 bytes: b'RIFF$\x14\x01\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\01-H2-Mi3.wav
# File: 01-H2-Mi3.wav
# Sample Rate: 44100 Hz
# Duration: 0.40 seconds
# Channels: 1
# 01-H2-Mi4.wav - First 20 bytes: b'RIFF$\x14\x01\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\01-H2-Mi4.wav
# File: 01-H2-Mi4.wav
# Sample Rate: 44100 Hz
# Duration: 0.40 seconds
# Channels: 1
# 01-H2-Mi5.wav - First 20 bytes: b'RIFF$\x14\x01\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\01-H2-Mi5.wav
# File: 01-H2-Mi5.wav
# Sample Rate: 44100 Hz
# Duration: 0.40 seconds
# Channels: 1
# 01-H2-Mi6.wav - First 20 bytes: b'RIFF$\x14\x01\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\01-H2-Mi6.wav
# File: 01-H2-Mi6.wav
# Sample Rate: 44100 Hz
# Duration: 0.40 seconds
# Channels: 1
# 01-HF-Mi1.wav - First 20 bytes: b'RIFF$d \x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\01-HF-Mi1.wav
# File: 01-HF-Mi1.wav
# Sample Rate: 44100 Hz
# Duration: 12.03 seconds
# Channels: 1
# 01-HF-Mi2.wav - First 20 bytes: b'RIFF$d \x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\01-HF-Mi2.wav
# File: 01-HF-Mi2.wav
# Sample Rate: 44100 Hz
# Duration: 12.03 seconds
# Channels: 1
# 01-HF-Mi3.wav - First 20 bytes: b'RIFF$d \x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\01-HF-Mi3.wav
# File: 01-HF-Mi3.wav
# Sample Rate: 44100 Hz
# Duration: 12.03 seconds
# Channels: 1
# 01-HF-Mi4.wav - First 20 bytes: b'RIFF$d \x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\01-HF-Mi4.wav
# File: 01-HF-Mi4.wav
# Sample Rate: 44100 Hz
# Duration: 12.03 seconds
# Channels: 1
# 01-HF-Mi5.wav - First 20 bytes: b'RIFF$d \x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\01-HF-Mi5.wav
# File: 01-HF-Mi5.wav
# Sample Rate: 44100 Hz
# Duration: 12.03 seconds
# Channels: 1
# 01-HF-Mi6.wav - First 20 bytes: b'RIFF$d \x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\01-HF-Mi6.wav
# File: 01-HF-Mi6.wav
# Sample Rate: 44100 Hz
# Duration: 12.03 seconds
# Channels: 1
# 01-LD-Mi1.wav - First 20 bytes: b'RIFF$\xc4\x00\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\01-LD-Mi1.wav
# File: 01-LD-Mi1.wav
# Sample Rate: 44100 Hz
# Duration: 0.28 seconds
# Channels: 1
# 01-LD-Mi2.wav - First 20 bytes: b'RIFF$\xc4\x00\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\01-LD-Mi2.wav
# File: 01-LD-Mi2.wav
# Sample Rate: 44100 Hz
# Duration: 0.28 seconds
# Channels: 1
# 01-LD-Mi3.wav - First 20 bytes: b'RIFF$\xc4\x00\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\01-LD-Mi3.wav
# File: 01-LD-Mi3.wav
# Sample Rate: 44100 Hz
# Duration: 0.28 seconds
# Channels: 1
# 01-LD-Mi4.wav - First 20 bytes: b'RIFF$\xc4\x00\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\01-LD-Mi4.wav
# File: 01-LD-Mi4.wav
# Sample Rate: 44100 Hz
# Duration: 0.28 seconds
# Channels: 1
# 01-LD-Mi5.wav - First 20 bytes: b'RIFF$\xc4\x00\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\01-LD-Mi5.wav
# File: 01-LD-Mi5.wav
# Sample Rate: 44100 Hz
# Duration: 0.28 seconds
# Channels: 1
# 01-LD-Mi6.wav - First 20 bytes: b'RIFF$\xc4\x00\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\01-LD-Mi6.wav
# File: 01-LD-Mi6.wav
# Sample Rate: 44100 Hz
# Duration: 0.28 seconds
# Channels: 1
# 01-TO-Mi1.wav - First 20 bytes: b'RIFF$\xdc)\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\01-TO-Mi1.wav
# File: 01-TO-Mi1.wav
# Sample Rate: 44100 Hz
# Duration: 15.55 seconds
# Channels: 1
# 01-TO-Mi2.wav - First 20 bytes: b'RIFF$\xdc)\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\01-TO-Mi2.wav
# File: 01-TO-Mi2.wav
# Sample Rate: 44100 Hz
# Duration: 15.55 seconds
# Channels: 1
# 01-TO-Mi3.wav - First 20 bytes: b'RIFF$\xdc)\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\01-TO-Mi3.wav
# File: 01-TO-Mi3.wav
# Sample Rate: 44100 Hz
# Duration: 15.55 seconds
# Channels: 1
# 01-TO-Mi4.wav - First 20 bytes: b'RIFF$\xdc)\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\01-TO-Mi4.wav
# File: 01-TO-Mi4.wav
# Sample Rate: 44100 Hz
# Duration: 15.55 seconds
# Channels: 1
# 01-TO-Mi5.wav - First 20 bytes: b'RIFF$\xdc)\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\01-TO-Mi5.wav
# File: 01-TO-Mi5.wav
# Sample Rate: 44100 Hz
# Duration: 15.55 seconds
# Channels: 1
# 01-TO-Mi6.wav - First 20 bytes: b'RIFF$\xdc)\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\01-TO-Mi6.wav
# File: 01-TO-Mi6.wav
# Sample Rate: 44100 Hz
# Duration: 15.55 seconds
# Channels: 1
# 02-FB-Mi1.wav - First 20 bytes: b'RIFF$\xf8\x01\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\02-FB-Mi1.wav
# File: 02-FB-Mi1.wav
# Sample Rate: 44100 Hz
# Duration: 0.73 seconds
# Channels: 1
# 02-FB-Mi2.wav - First 20 bytes: b'RIFF$\xf8\x01\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\02-FB-Mi2.wav
# File: 02-FB-Mi2.wav
# Sample Rate: 44100 Hz
# Duration: 0.73 seconds
# Channels: 1
# 02-FB-Mi3.wav - First 20 bytes: b'RIFF$\xf8\x01\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\02-FB-Mi3.wav
# File: 02-FB-Mi3.wav
# Sample Rate: 44100 Hz
# Duration: 0.73 seconds
# Channels: 1
# 02-FB-Mi4.wav - First 20 bytes: b'RIFF$\xf8\x01\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\02-FB-Mi4.wav
# File: 02-FB-Mi4.wav
# Sample Rate: 44100 Hz
# Duration: 0.73 seconds
# Channels: 1
# 02-FB-Mi5.wav - First 20 bytes: b'RIFF$\xf8\x01\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\02-FB-Mi5.wav
# File: 02-FB-Mi5.wav
# Sample Rate: 44100 Hz
# Duration: 0.73 seconds
# Channels: 1
# 02-FB-Mi6.wav - First 20 bytes: b'RIFF$\xf8\x01\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\02-FB-Mi6.wav
# File: 02-FB-Mi6.wav
# Sample Rate: 44100 Hz
# Duration: 0.73 seconds
# Channels: 1
# 02-FF-Mi1.wav - First 20 bytes: b'RIFF$L\x1d\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\02-FF-Mi1.wav
# File: 02-FF-Mi1.wav
# Sample Rate: 44100 Hz
# Duration: 10.88 seconds
# Channels: 1
# 02-FF-Mi2.wav - First 20 bytes: b'RIFF$L\x1d\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\02-FF-Mi2.wav
# File: 02-FF-Mi2.wav
# Sample Rate: 44100 Hz
# Duration: 10.88 seconds
# Channels: 1
# 02-FF-Mi3.wav - First 20 bytes: b'RIFF$L\x1d\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\02-FF-Mi3.wav
# File: 02-FF-Mi3.wav
# Sample Rate: 44100 Hz
# Duration: 10.88 seconds
# Channels: 1
# 02-FF-Mi4.wav - First 20 bytes: b'RIFF$L\x1d\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\02-FF-Mi4.wav
# File: 02-FF-Mi4.wav
# Sample Rate: 44100 Hz
# Duration: 10.88 seconds
# Channels: 1
# 02-FF-Mi5.wav - First 20 bytes: b'RIFF$L\x1d\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\02-FF-Mi5.wav
# File: 02-FF-Mi5.wav
# Sample Rate: 44100 Hz
# Duration: 10.88 seconds
# Channels: 1
# 02-FF-Mi6.wav - First 20 bytes: b'RIFF$L\x1d\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\02-FF-Mi6.wav
# File: 02-FF-Mi6.wav
# Sample Rate: 44100 Hz
# Duration: 10.88 seconds
# Channels: 1
# 02-H1-Mi1.wav - First 20 bytes: b'RIFF$H\x1e\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\02-H1-Mi1.wav
# File: 02-H1-Mi1.wav
# Sample Rate: 44100 Hz
# Duration: 11.25 seconds
# Channels: 1
# 02-H1-Mi2.wav - First 20 bytes: b'RIFF$H\x1e\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\02-H1-Mi2.wav
# File: 02-H1-Mi2.wav
# Sample Rate: 44100 Hz
# Duration: 11.25 seconds
# Channels: 1
# 02-H1-Mi3.wav - First 20 bytes: b'RIFF$H\x1e\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\02-H1-Mi3.wav
# File: 02-H1-Mi3.wav
# Sample Rate: 44100 Hz
# Duration: 11.25 seconds
# Channels: 1
# 02-H1-Mi4.wav - First 20 bytes: b'RIFF$H\x1e\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\02-H1-Mi4.wav
# File: 02-H1-Mi4.wav
# Sample Rate: 44100 Hz
# Duration: 11.25 seconds
# Channels: 1
# 02-H1-Mi5.wav - First 20 bytes: b'RIFF$H\x1e\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\02-H1-Mi5.wav
# File: 02-H1-Mi5.wav
# Sample Rate: 44100 Hz
# Duration: 11.25 seconds
# Channels: 1
# 02-H1-Mi6.wav - First 20 bytes: b'RIFF$H\x1e\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\02-H1-Mi6.wav
# File: 02-H1-Mi6.wav
# Sample Rate: 44100 Hz
# Duration: 11.25 seconds
# Channels: 1
# 02-H2-Mi1.wav - First 20 bytes: b'RIFF$\xe4\x00\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\02-H2-Mi1.wav
# File: 02-H2-Mi1.wav
# Sample Rate: 44100 Hz
# Duration: 0.33 seconds
# Channels: 1
# 02-H2-Mi2.wav - First 20 bytes: b'RIFF$\xe4\x00\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\02-H2-Mi2.wav
# File: 02-H2-Mi2.wav
# Sample Rate: 44100 Hz
# Duration: 0.33 seconds
# Channels: 1
# 02-H2-Mi3.wav - First 20 bytes: b'RIFF$\xe4\x00\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\02-H2-Mi3.wav
# File: 02-H2-Mi3.wav
# Sample Rate: 44100 Hz
# Duration: 0.33 seconds
# Channels: 1
# 02-H2-Mi4.wav - First 20 bytes: b'RIFF$\xe4\x00\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\02-H2-Mi4.wav
# File: 02-H2-Mi4.wav
# Sample Rate: 44100 Hz
# Duration: 0.33 seconds
# Channels: 1
# 02-H2-Mi5.wav - First 20 bytes: b'RIFF$\xe4\x00\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\02-H2-Mi5.wav
# File: 02-H2-Mi5.wav
# Sample Rate: 44100 Hz
# Duration: 0.33 seconds
# Channels: 1
# 02-H2-Mi6.wav - First 20 bytes: b'RIFF$\xe4\x00\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\02-H2-Mi6.wav
# File: 02-H2-Mi6.wav
# Sample Rate: 44100 Hz
# Duration: 0.33 seconds
# Channels: 1
# 02-HF-Mi1.wav - First 20 bytes: b'RIFF$\xe8\x18\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\02-HF-Mi1.wav
# File: 02-HF-Mi1.wav
# Sample Rate: 44100 Hz
# Duration: 9.25 seconds
# Channels: 1
# 02-HF-Mi2.wav - First 20 bytes: b'RIFF$\xe8\x18\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\02-HF-Mi2.wav
# File: 02-HF-Mi2.wav
# Sample Rate: 44100 Hz
# Duration: 9.25 seconds
# Channels: 1
# 02-HF-Mi3.wav - First 20 bytes: b'RIFF$\xe8\x18\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\02-HF-Mi3.wav
# File: 02-HF-Mi3.wav
# Sample Rate: 44100 Hz
# Duration: 9.25 seconds
# Channels: 1
# 02-HF-Mi4.wav - First 20 bytes: b'RIFF$\xe8\x18\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\02-HF-Mi4.wav
# File: 02-HF-Mi4.wav
# Sample Rate: 44100 Hz
# Duration: 9.25 seconds
# Channels: 1
# 02-HF-Mi5.wav - First 20 bytes: b'RIFF$\xe8\x18\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\02-HF-Mi5.wav
# File: 02-HF-Mi5.wav
# Sample Rate: 44100 Hz
# Duration: 9.25 seconds
# Channels: 1
# 02-HF-Mi6.wav - First 20 bytes: b'RIFF$\xe8\x18\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\02-HF-Mi6.wav
# File: 02-HF-Mi6.wav
# Sample Rate: 44100 Hz
# Duration: 9.25 seconds
# Channels: 1
# 02-LD-Mi1.wav - First 20 bytes: b'RIFF$\xd8\x00\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\02-LD-Mi1.wav
# File: 02-LD-Mi1.wav
# Sample Rate: 44100 Hz
# Duration: 0.31 seconds
# Channels: 1
# 02-LD-Mi2.wav - First 20 bytes: b'RIFF$\xd8\x00\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\02-LD-Mi2.wav
# File: 02-LD-Mi2.wav
# Sample Rate: 44100 Hz
# Duration: 0.31 seconds
# Channels: 1
# 02-LD-Mi3.wav - First 20 bytes: b'RIFF$\xd8\x00\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\02-LD-Mi3.wav
# File: 02-LD-Mi3.wav
# Sample Rate: 44100 Hz
# Duration: 0.31 seconds
# Channels: 1
# 02-LD-Mi4.wav - First 20 bytes: b'RIFF$\xd8\x00\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\02-LD-Mi4.wav
# File: 02-LD-Mi4.wav
# Sample Rate: 44100 Hz
# Duration: 0.31 seconds
# Channels: 1
# 02-LD-Mi5.wav - First 20 bytes: b'RIFF$\xd8\x00\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\02-LD-Mi5.wav
# File: 02-LD-Mi5.wav
# Sample Rate: 44100 Hz
# Duration: 0.31 seconds
# Channels: 1
# 02-LD-Mi6.wav - First 20 bytes: b'RIFF$\xd8\x00\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\02-LD-Mi6.wav
# File: 02-LD-Mi6.wav
# Sample Rate: 44100 Hz
# Duration: 0.31 seconds
# Channels: 1
# 02-TO-Mi1.wav - First 20 bytes: b'RIFF$\x98$\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\02-TO-Mi1.wav
# File: 02-TO-Mi1.wav
# Sample Rate: 44100 Hz
# Duration: 13.60 seconds
# Channels: 1
# 02-TO-Mi2.wav - First 20 bytes: b'RIFF$\x98$\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\02-TO-Mi2.wav
# File: 02-TO-Mi2.wav
# Sample Rate: 44100 Hz
# Duration: 13.60 seconds
# Channels: 1
# 02-TO-Mi3.wav - First 20 bytes: b'RIFF$\x98$\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\02-TO-Mi3.wav
# File: 02-TO-Mi3.wav
# Sample Rate: 44100 Hz
# Duration: 13.60 seconds
# Channels: 1
# 02-TO-Mi4.wav - First 20 bytes: b'RIFF$\x98$\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\02-TO-Mi4.wav
# File: 02-TO-Mi4.wav
# Sample Rate: 44100 Hz
# Duration: 13.60 seconds
# Channels: 1
# 02-TO-Mi5.wav - First 20 bytes: b'RIFF$\x98$\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\02-TO-Mi5.wav
# File: 02-TO-Mi5.wav
# Sample Rate: 44100 Hz
# Duration: 13.60 seconds
# Channels: 1
# 02-TO-Mi6.wav - First 20 bytes: b'RIFF$\x98$\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\02-TO-Mi6.wav
# File: 02-TO-Mi6.wav
# Sample Rate: 44100 Hz
# Duration: 13.60 seconds
# Channels: 1
# 03-FB-Mi1.wav - First 20 bytes: b'RIFF$\x80\x1e\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\03-FB-Mi1.wav
# File: 03-FB-Mi1.wav
# Sample Rate: 44100 Hz
# Duration: 11.33 seconds
# Channels: 1
# 03-FB-Mi2.wav - First 20 bytes: b'RIFF$\x80\x1e\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\03-FB-Mi2.wav
# File: 03-FB-Mi2.wav
# Sample Rate: 44100 Hz
# Duration: 11.33 seconds
# Channels: 1
# 03-FB-Mi3.wav - First 20 bytes: b'RIFF$\x80\x1e\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\03-FB-Mi3.wav
# File: 03-FB-Mi3.wav
# Sample Rate: 44100 Hz
# Duration: 11.33 seconds
# Channels: 1
# 03-FB-Mi4.wav - First 20 bytes: b'RIFF$\x80\x1e\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\03-FB-Mi4.wav
# File: 03-FB-Mi4.wav
# Sample Rate: 44100 Hz
# Duration: 11.33 seconds
# Channels: 1
# 03-FB-Mi5.wav - First 20 bytes: b'RIFF$\x80\x1e\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\03-FB-Mi5.wav
# File: 03-FB-Mi5.wav
# Sample Rate: 44100 Hz
# Duration: 11.33 seconds
# Channels: 1
# 03-FB-Mi6.wav - First 20 bytes: b'RIFF$\x80\x1e\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\03-FB-Mi6.wav
# File: 03-FB-Mi6.wav
# Sample Rate: 44100 Hz
# Duration: 11.33 seconds
# Channels: 1
# 03-FF-Mi1.wav - First 20 bytes: b'RIFF$0)\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\03-FF-Mi1.wav
# File: 03-FF-Mi1.wav
# Sample Rate: 44100 Hz
# Duration: 15.30 seconds
# Channels: 1
# 03-FF-Mi2.wav - First 20 bytes: b'RIFF$0)\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\03-FF-Mi2.wav
# File: 03-FF-Mi2.wav
# Sample Rate: 44100 Hz
# Duration: 15.30 seconds
# Channels: 1
# 03-FF-Mi3.wav - First 20 bytes: b'RIFF$0)\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\03-FF-Mi3.wav
# File: 03-FF-Mi3.wav
# Sample Rate: 44100 Hz
# Duration: 15.30 seconds
# Channels: 1
# 03-FF-Mi4.wav - First 20 bytes: b'RIFF$0)\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\03-FF-Mi4.wav
# File: 03-FF-Mi4.wav
# Sample Rate: 44100 Hz
# Duration: 15.30 seconds
# Channels: 1
# 03-FF-Mi5.wav - First 20 bytes: b'RIFF$0)\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\03-FF-Mi5.wav
# File: 03-FF-Mi5.wav
# Sample Rate: 44100 Hz
# Duration: 15.30 seconds
# Channels: 1
# 03-FF-Mi6.wav - First 20 bytes: b'RIFF$0)\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\03-FF-Mi6.wav
# File: 03-FF-Mi6.wav
# Sample Rate: 44100 Hz
# Duration: 15.30 seconds
# Channels: 1
# 03-H1-Mi1.wav - First 20 bytes: b'RIFF$d\x12\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\03-H1-Mi1.wav
# File: 03-H1-Mi1.wav
# Sample Rate: 44100 Hz
# Duration: 6.83 seconds
# Channels: 1
# 03-H1-Mi2.wav - First 20 bytes: b'RIFF$d\x12\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\03-H1-Mi2.wav
# File: 03-H1-Mi2.wav
# Sample Rate: 44100 Hz
# Duration: 6.83 seconds
# Channels: 1
# 03-H1-Mi3.wav - First 20 bytes: b'RIFF$d\x12\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\03-H1-Mi3.wav
# File: 03-H1-Mi3.wav
# Sample Rate: 44100 Hz
# Duration: 6.83 seconds
# Channels: 1
# 03-H1-Mi4.wav - First 20 bytes: b'RIFF$d\x12\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\03-H1-Mi4.wav
# File: 03-H1-Mi4.wav
# Sample Rate: 44100 Hz
# Duration: 6.83 seconds
# Channels: 1
# 03-H1-Mi5.wav - First 20 bytes: b'RIFF$d\x12\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\03-H1-Mi5.wav
# File: 03-H1-Mi5.wav
# Sample Rate: 44100 Hz
# Duration: 6.83 seconds
# Channels: 1
# 03-H1-Mi6.wav - First 20 bytes: b'RIFF$d\x12\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\03-H1-Mi6.wav
# File: 03-H1-Mi6.wav
# Sample Rate: 44100 Hz
# Duration: 6.83 seconds
# Channels: 1
# 03-H2-Mi1.wav - First 20 bytes: b'RIFF$\xe4\x0e\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\03-H2-Mi1.wav
# File: 03-H2-Mi1.wav
# Sample Rate: 44100 Hz
# Duration: 5.53 seconds
# Channels: 1
# 03-H2-Mi2.wav - First 20 bytes: b'RIFF$\xe4\x0e\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\03-H2-Mi2.wav
# File: 03-H2-Mi2.wav
# Sample Rate: 44100 Hz
# Duration: 5.53 seconds
# Channels: 1
# 03-H2-Mi3.wav - First 20 bytes: b'RIFF$\xe4\x0e\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\03-H2-Mi3.wav
# File: 03-H2-Mi3.wav
# Sample Rate: 44100 Hz
# Duration: 5.53 seconds
# Channels: 1
# 03-H2-Mi4.wav - First 20 bytes: b'RIFF$\xe4\x0e\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\03-H2-Mi4.wav
# File: 03-H2-Mi4.wav
# Sample Rate: 44100 Hz
# Duration: 5.53 seconds
# Channels: 1
# 03-H2-Mi5.wav - First 20 bytes: b'RIFF$\xe4\x0e\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\03-H2-Mi5.wav
# File: 03-H2-Mi5.wav
# Sample Rate: 44100 Hz
# Duration: 5.53 seconds
# Channels: 1
# 03-H2-Mi6.wav - First 20 bytes: b'RIFF$\xe4\x0e\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\03-H2-Mi6.wav
# File: 03-H2-Mi6.wav
# Sample Rate: 44100 Hz
# Duration: 5.53 seconds
# Channels: 1
# 03-HF-Mi1.wav - First 20 bytes: b'RIFF$t\x11\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\03-HF-Mi1.wav
# File: 03-HF-Mi1.wav
# Sample Rate: 44100 Hz
# Duration: 6.48 seconds
# Channels: 1
# 03-HF-Mi2.wav - First 20 bytes: b'RIFF$t\x11\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\03-HF-Mi2.wav
# File: 03-HF-Mi2.wav
# Sample Rate: 44100 Hz
# Duration: 6.48 seconds
# Channels: 1
# 03-HF-Mi3.wav - First 20 bytes: b'RIFF$t\x11\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\03-HF-Mi3.wav
# File: 03-HF-Mi3.wav
# Sample Rate: 44100 Hz
# Duration: 6.48 seconds
# Channels: 1
# 03-HF-Mi4.wav - First 20 bytes: b'RIFF$t\x11\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\03-HF-Mi4.wav
# File: 03-HF-Mi4.wav
# Sample Rate: 44100 Hz
# Duration: 6.48 seconds
# Channels: 1
# 03-HF-Mi5.wav - First 20 bytes: b'RIFF$t\x11\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\03-HF-Mi5.wav
# File: 03-HF-Mi5.wav
# Sample Rate: 44100 Hz
# Duration: 6.48 seconds
# Channels: 1
# 03-HF-Mi6.wav - First 20 bytes: b'RIFF$t\x11\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\03-HF-Mi6.wav
# File: 03-HF-Mi6.wav
# Sample Rate: 44100 Hz
# Duration: 6.48 seconds
# Channels: 1
# 03-LD-Mi1.wav - First 20 bytes: b'RIFF$\x00%\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\03-LD-Mi1.wav
# File: 03-LD-Mi1.wav
# Sample Rate: 44100 Hz
# Duration: 13.75 seconds
# Channels: 1
# 03-LD-Mi2.wav - First 20 bytes: b'RIFF$\x00%\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\03-LD-Mi2.wav
# File: 03-LD-Mi2.wav
# Sample Rate: 44100 Hz
# Duration: 13.75 seconds
# Channels: 1
# 03-LD-Mi3.wav - First 20 bytes: b'RIFF$\x00%\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\03-LD-Mi3.wav
# File: 03-LD-Mi3.wav
# Sample Rate: 44100 Hz
# Duration: 13.75 seconds
# Channels: 1
# 03-LD-Mi4.wav - First 20 bytes: b'RIFF$\x00%\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\03-LD-Mi4.wav
# File: 03-LD-Mi4.wav
# Sample Rate: 44100 Hz
# Duration: 13.75 seconds
# Channels: 1
# 03-LD-Mi5.wav - First 20 bytes: b'RIFF$\x00%\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\03-LD-Mi5.wav
# File: 03-LD-Mi5.wav
# Sample Rate: 44100 Hz
# Duration: 13.75 seconds
# Channels: 1
# 03-LD-Mi6.wav - First 20 bytes: b'RIFF$\x00%\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\03-LD-Mi6.wav
# File: 03-LD-Mi6.wav
# Sample Rate: 44100 Hz
# Duration: 13.75 seconds
# Channels: 1
# 03-TO-Mi1.wav - First 20 bytes: b'RIFF$\x00#\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\03-TO-Mi1.wav
# File: 03-TO-Mi1.wav
# Sample Rate: 44100 Hz
# Duration: 13.00 seconds
# Channels: 1
# 03-TO-Mi2.wav - First 20 bytes: b'RIFF$\x00#\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\03-TO-Mi2.wav
# File: 03-TO-Mi2.wav
# Sample Rate: 44100 Hz
# Duration: 13.00 seconds
# Channels: 1
# 03-TO-Mi3.wav - First 20 bytes: b'RIFF$\x00#\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\03-TO-Mi3.wav
# File: 03-TO-Mi3.wav
# Sample Rate: 44100 Hz
# Duration: 13.00 seconds
# Channels: 1
# 03-TO-Mi4.wav - First 20 bytes: b'RIFF$\x00#\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\03-TO-Mi4.wav
# File: 03-TO-Mi4.wav
# Sample Rate: 44100 Hz
# Duration: 13.00 seconds
# Channels: 1
# 03-TO-Mi5.wav - First 20 bytes: b'RIFF$\x00#\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\03-TO-Mi5.wav
# File: 03-TO-Mi5.wav
# Sample Rate: 44100 Hz
# Duration: 13.00 seconds
# Channels: 1
# 03-TO-Mi6.wav - First 20 bytes: b'RIFF$\x00#\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\03-TO-Mi6.wav
# File: 03-TO-Mi6.wav
# Sample Rate: 44100 Hz
# Duration: 13.00 seconds
# Channels: 1
# 04-FB-Mi1.wav - First 20 bytes: b'RIFF$\x940\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\04-FB-Mi1.wav
# File: 04-FB-Mi1.wav
# Sample Rate: 44100 Hz
# Duration: 18.05 seconds
# Channels: 1
# 04-FB-Mi2.wav - First 20 bytes: b'RIFF$\x940\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\04-FB-Mi2.wav
# File: 04-FB-Mi2.wav
# Sample Rate: 44100 Hz
# Duration: 18.05 seconds
# Channels: 1
# 04-FB-Mi3.wav - First 20 bytes: b'RIFF$\x940\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\04-FB-Mi3.wav
# File: 04-FB-Mi3.wav
# Sample Rate: 44100 Hz
# Duration: 18.05 seconds
# Channels: 1
# 04-FB-Mi4.wav - First 20 bytes: b'RIFF$\x940\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\04-FB-Mi4.wav
# File: 04-FB-Mi4.wav
# Sample Rate: 44100 Hz
# Duration: 18.05 seconds
# Channels: 1
# 04-FB-Mi5.wav - First 20 bytes: b'RIFF$\x940\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\04-FB-Mi5.wav
# File: 04-FB-Mi5.wav
# Sample Rate: 44100 Hz
# Duration: 18.05 seconds
# Channels: 1
# 04-FB-Mi6.wav - First 20 bytes: b'RIFF$\x940\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\04-FB-Mi6.wav
# File: 04-FB-Mi6.wav
# Sample Rate: 44100 Hz
# Duration: 18.05 seconds
# Channels: 1
# 04-FF-Mi1.wav - First 20 bytes: b'RIFF$\xe8,\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\04-FF-Mi1.wav
# File: 04-FF-Mi1.wav
# Sample Rate: 44100 Hz
# Duration: 16.68 seconds
# Channels: 1
# 04-FF-Mi2.wav - First 20 bytes: b'RIFF$\xe8,\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\04-FF-Mi2.wav
# File: 04-FF-Mi2.wav
# Sample Rate: 44100 Hz
# Duration: 16.68 seconds
# Channels: 1
# 04-FF-Mi3.wav - First 20 bytes: b'RIFF$\xe8,\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\04-FF-Mi3.wav
# File: 04-FF-Mi3.wav
# Sample Rate: 44100 Hz
# Duration: 16.68 seconds
# Channels: 1
# 04-FF-Mi4.wav - First 20 bytes: b'RIFF$\xe8,\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\04-FF-Mi4.wav
# File: 04-FF-Mi4.wav
# Sample Rate: 44100 Hz
# Duration: 16.68 seconds
# Channels: 1
# 04-FF-Mi5.wav - First 20 bytes: b'RIFF$\xe8,\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\04-FF-Mi5.wav
# File: 04-FF-Mi5.wav
# Sample Rate: 44100 Hz
# Duration: 16.68 seconds
# Channels: 1
# 04-FF-Mi6.wav - First 20 bytes: b'RIFF$\xe8,\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\04-FF-Mi6.wav
# File: 04-FF-Mi6.wav
# Sample Rate: 44100 Hz
# Duration: 16.68 seconds
# Channels: 1
# 04-H1-Mi1.wav - First 20 bytes: b'RIFF$\xb4\x0f\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\04-H1-Mi1.wav
# File: 04-H1-Mi1.wav
# Sample Rate: 44100 Hz
# Duration: 5.83 seconds
# Channels: 1
# 04-H1-Mi2.wav - First 20 bytes: b'RIFF$\xb4\x0f\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\04-H1-Mi2.wav
# File: 04-H1-Mi2.wav
# Sample Rate: 44100 Hz
# Duration: 5.83 seconds
# Channels: 1
# 04-H1-Mi3.wav - First 20 bytes: b'RIFF$\xb4\x0f\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\04-H1-Mi3.wav
# File: 04-H1-Mi3.wav
# Sample Rate: 44100 Hz
# Duration: 5.83 seconds
# Channels: 1
# 04-H1-Mi4.wav - First 20 bytes: b'RIFF$\xb4\x0f\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\04-H1-Mi4.wav
# File: 04-H1-Mi4.wav
# Sample Rate: 44100 Hz
# Duration: 5.83 seconds
# Channels: 1
# 04-H1-Mi5.wav - First 20 bytes: b'RIFF$\xb4\x0f\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\04-H1-Mi5.wav
# File: 04-H1-Mi5.wav
# Sample Rate: 44100 Hz
# Duration: 5.83 seconds
# Channels: 1
# 04-H1-Mi6.wav - First 20 bytes: b'RIFF$\xb4\x0f\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\04-H1-Mi6.wav
# File: 04-H1-Mi6.wav
# Sample Rate: 44100 Hz
# Duration: 5.83 seconds
# Channels: 1
# 04-H2-Mi1.wav - First 20 bytes: b'RIFF$\xa8\x13\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\04-H2-Mi1.wav
# File: 04-H2-Mi1.wav
# Sample Rate: 44100 Hz
# Duration: 7.30 seconds
# Channels: 1
# 04-H2-Mi2.wav - First 20 bytes: b'RIFF$\xa8\x13\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\04-H2-Mi2.wav
# File: 04-H2-Mi2.wav
# Sample Rate: 44100 Hz
# Duration: 7.30 seconds
# Channels: 1
# 04-H2-Mi3.wav - First 20 bytes: b'RIFF$\xa8\x13\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\04-H2-Mi3.wav
# File: 04-H2-Mi3.wav
# Sample Rate: 44100 Hz
# Duration: 7.30 seconds
# Channels: 1
# 04-H2-Mi4.wav - First 20 bytes: b'RIFF$\xa8\x13\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\04-H2-Mi4.wav
# File: 04-H2-Mi4.wav
# Sample Rate: 44100 Hz
# Duration: 7.30 seconds
# Channels: 1
# 04-H2-Mi5.wav - First 20 bytes: b'RIFF$\xa8\x13\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\04-H2-Mi5.wav
# File: 04-H2-Mi5.wav
# Sample Rate: 44100 Hz
# Duration: 7.30 seconds
# Channels: 1
# 04-H2-Mi6.wav - First 20 bytes: b'RIFF$\xa8\x13\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\04-H2-Mi6.wav
# File: 04-H2-Mi6.wav
# Sample Rate: 44100 Hz
# Duration: 7.30 seconds
# Channels: 1
# 04-HF-Mi1.wav - First 20 bytes: b'RIFF$\x88\x11\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\04-HF-Mi1.wav
# File: 04-HF-Mi1.wav
# Sample Rate: 44100 Hz
# Duration: 6.51 seconds
# Channels: 1
# 04-HF-Mi2.wav - First 20 bytes: b'RIFF$\x88\x11\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\04-HF-Mi2.wav
# File: 04-HF-Mi2.wav
# Sample Rate: 44100 Hz
# Duration: 6.51 seconds
# Channels: 1
# 04-HF-Mi3.wav - First 20 bytes: b'RIFF$\x88\x11\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\04-HF-Mi3.wav
# File: 04-HF-Mi3.wav
# Sample Rate: 44100 Hz
# Duration: 6.51 seconds
# Channels: 1
# 04-HF-Mi4.wav - First 20 bytes: b'RIFF$\x88\x11\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\04-HF-Mi4.wav
# File: 04-HF-Mi4.wav
# Sample Rate: 44100 Hz
# Duration: 6.51 seconds
# Channels: 1
# 04-HF-Mi5.wav - First 20 bytes: b'RIFF$\x88\x11\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\04-HF-Mi5.wav
# File: 04-HF-Mi5.wav
# Sample Rate: 44100 Hz
# Duration: 6.51 seconds
# Channels: 1
# 04-HF-Mi6.wav - First 20 bytes: b'RIFF$\x88\x11\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\04-HF-Mi6.wav
# File: 04-HF-Mi6.wav
# Sample Rate: 44100 Hz
# Duration: 6.51 seconds
# Channels: 1
# 04-LD-Mi1.wav - First 20 bytes: b'RIFF$\xf8)\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\04-LD-Mi1.wav
# File: 04-LD-Mi1.wav
# Sample Rate: 44100 Hz
# Duration: 15.59 seconds
# Channels: 1
# 04-LD-Mi2.wav - First 20 bytes: b'RIFF$\xf8)\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\04-LD-Mi2.wav
# File: 04-LD-Mi2.wav
# Sample Rate: 44100 Hz
# Duration: 15.59 seconds
# Channels: 1
# 04-LD-Mi3.wav - First 20 bytes: b'RIFF$\xfc)\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\04-LD-Mi3.wav
# File: 04-LD-Mi3.wav
# Sample Rate: 44100 Hz
# Duration: 15.60 seconds
# Channels: 1
# 04-LD-Mi4.wav - First 20 bytes: b'RIFF$\x00*\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\04-LD-Mi4.wav
# File: 04-LD-Mi4.wav
# Sample Rate: 44100 Hz
# Duration: 15.60 seconds
# Channels: 1
# 04-LD-Mi5.wav - First 20 bytes: b'RIFF$\x00*\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\04-LD-Mi5.wav
# File: 04-LD-Mi5.wav
# Sample Rate: 44100 Hz
# Duration: 15.60 seconds
# Channels: 1
# 04-LD-Mi6.wav - First 20 bytes: b'RIFF$\x00*\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\04-LD-Mi6.wav
# File: 04-LD-Mi6.wav
# Sample Rate: 44100 Hz
# Duration: 15.60 seconds
# Channels: 1
# 04-TO-Mi1.wav - First 20 bytes: b'RIFF$,\x1f\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\04-TO-Mi1.wav
# File: 04-TO-Mi1.wav
# Sample Rate: 44100 Hz
# Duration: 11.58 seconds
# Channels: 1
# 04-TO-Mi2.wav - First 20 bytes: b'RIFF$,\x1f\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\04-TO-Mi2.wav
# File: 04-TO-Mi2.wav
# Sample Rate: 44100 Hz
# Duration: 11.58 seconds
# Channels: 1
# 04-TO-Mi3.wav - First 20 bytes: b'RIFF$,\x1f\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\04-TO-Mi3.wav
# File: 04-TO-Mi3.wav
# Sample Rate: 44100 Hz
# Duration: 11.58 seconds
# Channels: 1
# 04-TO-Mi4.wav - First 20 bytes: b'RIFF$,\x1f\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\04-TO-Mi4.wav
# File: 04-TO-Mi4.wav
# Sample Rate: 44100 Hz
# Duration: 11.58 seconds
# Channels: 1
# 04-TO-Mi5.wav - First 20 bytes: b'RIFF$,\x1f\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\04-TO-Mi5.wav
# File: 04-TO-Mi5.wav
# Sample Rate: 44100 Hz
# Duration: 11.58 seconds
# Channels: 1
# 04-TO-Mi6.wav - First 20 bytes: b'RIFF$,\x1f\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\04-TO-Mi6.wav
# File: 04-TO-Mi6.wav
# Sample Rate: 44100 Hz
# Duration: 11.58 seconds
# Channels: 1
# 05-FB-Mi1.wav - First 20 bytes: b'RIFF$\xc8\x10\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\05-FB-Mi1.wav
# File: 05-FB-Mi1.wav
# Sample Rate: 44100 Hz
# Duration: 6.23 seconds
# Channels: 1
# 05-FB-Mi2.wav - First 20 bytes: b'RIFF$\xc8\x10\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\05-FB-Mi2.wav
# File: 05-FB-Mi2.wav
# Sample Rate: 44100 Hz
# Duration: 6.23 seconds
# Channels: 1
# 05-FB-Mi3.wav - First 20 bytes: b'RIFF$\xc8\x10\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\05-FB-Mi3.wav
# File: 05-FB-Mi3.wav
# Sample Rate: 44100 Hz
# Duration: 6.23 seconds
# Channels: 1
# 05-FB-Mi4.wav - First 20 bytes: b'RIFF$\xc8\x10\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\05-FB-Mi4.wav
# File: 05-FB-Mi4.wav
# Sample Rate: 44100 Hz
# Duration: 6.23 seconds
# Channels: 1
# 05-FB-Mi5.wav - First 20 bytes: b'RIFF$\xc8\x10\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\05-FB-Mi5.wav
# File: 05-FB-Mi5.wav
# Sample Rate: 44100 Hz
# Duration: 6.23 seconds
# Channels: 1
# 05-FB-Mi6.wav - First 20 bytes: b'RIFF$\xc8\x10\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\05-FB-Mi6.wav
# File: 05-FB-Mi6.wav
# Sample Rate: 44100 Hz
# Duration: 6.23 seconds
# Channels: 1
# 05-FF-Mi1.wav - First 20 bytes: b'RIFF$t\x1b\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\05-FF-Mi1.wav
# File: 05-FF-Mi1.wav
# Sample Rate: 44100 Hz
# Duration: 10.20 seconds
# Channels: 1
# 05-FF-Mi2.wav - First 20 bytes: b'RIFF$t\x1b\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\05-FF-Mi2.wav
# File: 05-FF-Mi2.wav
# Sample Rate: 44100 Hz
# Duration: 10.20 seconds
# Channels: 1
# 05-FF-Mi3.wav - First 20 bytes: b'RIFF$t\x1b\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\05-FF-Mi3.wav
# File: 05-FF-Mi3.wav
# Sample Rate: 44100 Hz
# Duration: 10.20 seconds
# Channels: 1
# 05-FF-Mi4.wav - First 20 bytes: b'RIFF$t\x1b\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\05-FF-Mi4.wav
# File: 05-FF-Mi4.wav
# Sample Rate: 44100 Hz
# Duration: 10.20 seconds
# Channels: 1
# 05-FF-Mi5.wav - First 20 bytes: b'RIFF$t\x1b\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\05-FF-Mi5.wav
# File: 05-FF-Mi5.wav
# Sample Rate: 44100 Hz
# Duration: 10.20 seconds
# Channels: 1
# 05-FF-Mi6.wav - First 20 bytes: b'RIFF$t\x1b\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\05-FF-Mi6.wav
# File: 05-FF-Mi6.wav
# Sample Rate: 44100 Hz
# Duration: 10.20 seconds
# Channels: 1
# 05-H1-Mi1.wav - First 20 bytes: b'RIFF$\xcc\x12\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\05-H1-Mi1.wav
# File: 05-H1-Mi1.wav
# Sample Rate: 44100 Hz
# Duration: 6.98 seconds
# Channels: 1
# 05-H1-Mi2.wav - First 20 bytes: b'RIFF$\xcc\x12\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\05-H1-Mi2.wav
# File: 05-H1-Mi2.wav
# Sample Rate: 44100 Hz
# Duration: 6.98 seconds
# Channels: 1
# 05-H1-Mi3.wav - First 20 bytes: b'RIFF$\xcc\x12\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\05-H1-Mi3.wav
# File: 05-H1-Mi3.wav
# Sample Rate: 44100 Hz
# Duration: 6.98 seconds
# Channels: 1
# 05-H1-Mi4.wav - First 20 bytes: b'RIFF$\xcc\x12\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\05-H1-Mi4.wav
# File: 05-H1-Mi4.wav
# Sample Rate: 44100 Hz
# Duration: 6.98 seconds
# Channels: 1
# 05-H1-Mi5.wav - First 20 bytes: b'RIFF$\xcc\x12\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\05-H1-Mi5.wav
# File: 05-H1-Mi5.wav
# Sample Rate: 44100 Hz
# Duration: 6.98 seconds
# Channels: 1
# 05-H1-Mi6.wav - First 20 bytes: b'RIFF$\xcc\x12\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\05-H1-Mi6.wav
# File: 05-H1-Mi6.wav
# Sample Rate: 44100 Hz
# Duration: 6.98 seconds
# Channels: 1
# 05-H2-Mi1.wav - First 20 bytes: b'RIFF$T\x10\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\05-H2-Mi1.wav
# File: 05-H2-Mi1.wav
# Sample Rate: 44100 Hz
# Duration: 6.07 seconds
# Channels: 1
# 05-H2-Mi2.wav - First 20 bytes: b'RIFF$T\x10\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\05-H2-Mi2.wav
# File: 05-H2-Mi2.wav
# Sample Rate: 44100 Hz
# Duration: 6.07 seconds
# Channels: 1
# 05-H2-Mi3.wav - First 20 bytes: b'RIFF$T\x10\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\05-H2-Mi3.wav
# File: 05-H2-Mi3.wav
# Sample Rate: 44100 Hz
# Duration: 6.07 seconds
# Channels: 1
# 05-H2-Mi4.wav - First 20 bytes: b'RIFF$T\x10\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\05-H2-Mi4.wav
# File: 05-H2-Mi4.wav
# Sample Rate: 44100 Hz
# Duration: 6.07 seconds
# Channels: 1
# 05-H2-Mi5.wav - First 20 bytes: b'RIFF$T\x10\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\05-H2-Mi5.wav
# File: 05-H2-Mi5.wav
# Sample Rate: 44100 Hz
# Duration: 6.07 seconds
# Channels: 1
# 05-H2-Mi6.wav - First 20 bytes: b'RIFF$T\x10\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\05-H2-Mi6.wav
# File: 05-H2-Mi6.wav
# Sample Rate: 44100 Hz
# Duration: 6.07 seconds
# Channels: 1
# 05-HF-Mi1.wav - First 20 bytes: b'RIFF$\x1c\x10\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\05-HF-Mi1.wav
# File: 05-HF-Mi1.wav
# Sample Rate: 44100 Hz
# Duration: 5.98 seconds
# Channels: 1
# 05-HF-Mi2.wav - First 20 bytes: b'RIFF$\x1c\x10\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\05-HF-Mi2.wav
# File: 05-HF-Mi2.wav
# Sample Rate: 44100 Hz
# Duration: 5.98 seconds
# Channels: 1
# 05-HF-Mi3.wav - First 20 bytes: b'RIFF$\x1c\x10\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\05-HF-Mi3.wav
# File: 05-HF-Mi3.wav
# Sample Rate: 44100 Hz
# Duration: 5.98 seconds
# Channels: 1
# 05-HF-Mi4.wav - First 20 bytes: b'RIFF$\x1c\x10\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\05-HF-Mi4.wav
# File: 05-HF-Mi4.wav
# Sample Rate: 44100 Hz
# Duration: 5.98 seconds
# Channels: 1
# 05-HF-Mi5.wav - First 20 bytes: b'RIFF$\x1c\x10\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\05-HF-Mi5.wav
# File: 05-HF-Mi5.wav
# Sample Rate: 44100 Hz
# Duration: 5.98 seconds
# Channels: 1
# 05-HF-Mi6.wav - First 20 bytes: b'RIFF$\x1c\x10\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\05-HF-Mi6.wav
# File: 05-HF-Mi6.wav
# Sample Rate: 44100 Hz
# Duration: 5.98 seconds
# Channels: 1
# 05-LD-Mi1.wav - First 20 bytes: b'RIFF$\x94&\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\05-LD-Mi1.wav
# File: 05-LD-Mi1.wav
# Sample Rate: 44100 Hz
# Duration: 14.33 seconds
# Channels: 1
# 05-LD-Mi2.wav - First 20 bytes: b'RIFF$\x94&\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\05-LD-Mi2.wav
# File: 05-LD-Mi2.wav
# Sample Rate: 44100 Hz
# Duration: 14.33 seconds
# Channels: 1
# 05-LD-Mi3.wav - First 20 bytes: b'RIFF$\x94&\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\05-LD-Mi3.wav
# File: 05-LD-Mi3.wav
# Sample Rate: 44100 Hz
# Duration: 14.33 seconds
# Channels: 1
# 05-LD-Mi4.wav - First 20 bytes: b'RIFF$\x94&\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\05-LD-Mi4.wav
# File: 05-LD-Mi4.wav
# Sample Rate: 44100 Hz
# Duration: 14.33 seconds
# Channels: 1
# 05-LD-Mi5.wav - First 20 bytes: b'RIFF$\x94&\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\05-LD-Mi5.wav
# File: 05-LD-Mi5.wav
# Sample Rate: 44100 Hz
# Duration: 14.33 seconds
# Channels: 1
# 05-LD-Mi6.wav - First 20 bytes: b'RIFF$\x94&\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\05-LD-Mi6.wav
# File: 05-LD-Mi6.wav
# Sample Rate: 44100 Hz
# Duration: 14.33 seconds
# Channels: 1
# 05-TO-Mi1.wav - First 20 bytes: b'RIFF$\xc0\x1d\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\05-TO-Mi1.wav
# File: 05-TO-Mi1.wav
# Sample Rate: 44100 Hz
# Duration: 11.05 seconds
# Channels: 1
# 05-TO-Mi2.wav - First 20 bytes: b'RIFF$\xc0\x1d\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\05-TO-Mi2.wav
# File: 05-TO-Mi2.wav
# Sample Rate: 44100 Hz
# Duration: 11.05 seconds
# Channels: 1
# 05-TO-Mi3.wav - First 20 bytes: b'RIFF$\xc0\x1d\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\05-TO-Mi3.wav
# File: 05-TO-Mi3.wav
# Sample Rate: 44100 Hz
# Duration: 11.05 seconds
# Channels: 1
# 05-TO-Mi4.wav - First 20 bytes: b'RIFF$\xc0\x1d\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\05-TO-Mi4.wav
# File: 05-TO-Mi4.wav
# Sample Rate: 44100 Hz
# Duration: 11.05 seconds
# Channels: 1
# 05-TO-Mi5.wav - First 20 bytes: b'RIFF$\xc0\x1d\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\05-TO-Mi5.wav
# File: 05-TO-Mi5.wav
# Sample Rate: 44100 Hz
# Duration: 11.05 seconds
# Channels: 1
# 05-TO-Mi6.wav - First 20 bytes: b'RIFF$\xc0\x1d\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\05-TO-Mi6.wav
# File: 05-TO-Mi6.wav
# Sample Rate: 44100 Hz
# Duration: 11.05 seconds
# Channels: 1
# 06-FB-Mi1.wav - First 20 bytes: b'RIFF$\x8c3\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\06-FB-Mi1.wav
# File: 06-FB-Mi1.wav
# Sample Rate: 44100 Hz
# Duration: 19.15 seconds
# Channels: 1
# 06-FB-Mi2.wav - First 20 bytes: b'RIFF$\x8c3\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\06-FB-Mi2.wav
# File: 06-FB-Mi2.wav
# Sample Rate: 44100 Hz
# Duration: 19.15 seconds
# Channels: 1
# 06-FB-Mi3.wav - First 20 bytes: b'RIFF$\x8c3\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\06-FB-Mi3.wav
# File: 06-FB-Mi3.wav
# Sample Rate: 44100 Hz
# Duration: 19.15 seconds
# Channels: 1
# 06-FB-Mi4.wav - First 20 bytes: b'RIFF$\x8c3\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\06-FB-Mi4.wav
# File: 06-FB-Mi4.wav
# Sample Rate: 44100 Hz
# Duration: 19.15 seconds
# Channels: 1
# 06-FB-Mi5.wav - First 20 bytes: b'RIFF$\x8c3\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\06-FB-Mi5.wav
# File: 06-FB-Mi5.wav
# Sample Rate: 44100 Hz
# Duration: 19.15 seconds
# Channels: 1
# 06-FB-Mi6.wav - First 20 bytes: b'RIFF$\x8c3\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\06-FB-Mi6.wav
# File: 06-FB-Mi6.wav
# Sample Rate: 44100 Hz
# Duration: 19.15 seconds
# Channels: 1
# 06-FF-Mi1.wav - First 20 bytes: b'RIFF$tE\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\06-FF-Mi1.wav
# File: 06-FF-Mi1.wav
# Sample Rate: 44100 Hz
# Duration: 25.80 seconds
# Channels: 1
# 06-FF-Mi2.wav - First 20 bytes: b'RIFF$tE\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\06-FF-Mi2.wav
# File: 06-FF-Mi2.wav
# Sample Rate: 44100 Hz
# Duration: 25.80 seconds
# Channels: 1
# 06-FF-Mi3.wav - First 20 bytes: b'RIFF$tE\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\06-FF-Mi3.wav
# File: 06-FF-Mi3.wav
# Sample Rate: 44100 Hz
# Duration: 25.80 seconds
# Channels: 1
# 06-FF-Mi4.wav - First 20 bytes: b'RIFF$tE\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\06-FF-Mi4.wav
# File: 06-FF-Mi4.wav
# Sample Rate: 44100 Hz
# Duration: 25.80 seconds
# Channels: 1
# 06-FF-Mi5.wav - First 20 bytes: b'RIFF$tE\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\06-FF-Mi5.wav
# File: 06-FF-Mi5.wav
# Sample Rate: 44100 Hz
# Duration: 25.80 seconds
# Channels: 1
# 06-FF-Mi6.wav - First 20 bytes: b'RIFF$tE\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\06-FF-Mi6.wav
# File: 06-FF-Mi6.wav
# Sample Rate: 44100 Hz
# Duration: 25.80 seconds
# Channels: 1
# 06-H1-Mi1.wav - First 20 bytes: b'RIFF$ \x12\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\06-H1-Mi1.wav
# File: 06-H1-Mi1.wav
# Sample Rate: 44100 Hz
# Duration: 6.73 seconds
# Channels: 1
# 06-H1-Mi2.wav - First 20 bytes: b'RIFF$ \x12\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\06-H1-Mi2.wav
# File: 06-H1-Mi2.wav
# Sample Rate: 44100 Hz
# Duration: 6.73 seconds
# Channels: 1
# 06-H1-Mi3.wav - First 20 bytes: b'RIFF$ \x12\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\06-H1-Mi3.wav
# File: 06-H1-Mi3.wav
# Sample Rate: 44100 Hz
# Duration: 6.73 seconds
# Channels: 1
# 06-H1-Mi4.wav - First 20 bytes: b'RIFF$ \x12\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\06-H1-Mi4.wav
# File: 06-H1-Mi4.wav
# Sample Rate: 44100 Hz
# Duration: 6.73 seconds
# Channels: 1
# 06-H1-Mi5.wav - First 20 bytes: b'RIFF$ \x12\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\06-H1-Mi5.wav
# File: 06-H1-Mi5.wav
# Sample Rate: 44100 Hz
# Duration: 6.73 seconds
# Channels: 1
# 06-H1-Mi6.wav - First 20 bytes: b'RIFF$ \x12\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\06-H1-Mi6.wav
# File: 06-H1-Mi6.wav
# Sample Rate: 44100 Hz
# Duration: 6.73 seconds
# Channels: 1
# 06-H2-Mi1.wav - First 20 bytes: b'RIFF$L\x13\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\06-H2-Mi1.wav
# File: 06-H2-Mi1.wav
# Sample Rate: 44100 Hz
# Duration: 7.17 seconds
# Channels: 1
# 06-H2-Mi2.wav - First 20 bytes: b'RIFF$L\x13\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\06-H2-Mi2.wav
# File: 06-H2-Mi2.wav
# Sample Rate: 44100 Hz
# Duration: 7.17 seconds
# Channels: 1
# 06-H2-Mi3.wav - First 20 bytes: b'RIFF$L\x13\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\06-H2-Mi3.wav
# File: 06-H2-Mi3.wav
# Sample Rate: 44100 Hz
# Duration: 7.17 seconds
# Channels: 1
# 06-H2-Mi4.wav - First 20 bytes: b'RIFF$L\x13\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\06-H2-Mi4.wav
# File: 06-H2-Mi4.wav
# Sample Rate: 44100 Hz
# Duration: 7.17 seconds
# Channels: 1
# 06-H2-Mi5.wav - First 20 bytes: b'RIFF$L\x13\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\06-H2-Mi5.wav
# File: 06-H2-Mi5.wav
# Sample Rate: 44100 Hz
# Duration: 7.17 seconds
# Channels: 1
# 06-H2-Mi6.wav - First 20 bytes: b'RIFF$L\x13\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\06-H2-Mi6.wav
# File: 06-H2-Mi6.wav
# Sample Rate: 44100 Hz
# Duration: 7.17 seconds
# Channels: 1
# 06-HF-Mi1.wav - First 20 bytes: b'RIFF$L\x12\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\06-HF-Mi1.wav
# File: 06-HF-Mi1.wav
# Sample Rate: 44100 Hz
# Duration: 6.80 seconds
# Channels: 1
# 06-HF-Mi2.wav - First 20 bytes: b'RIFF$L\x12\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\06-HF-Mi2.wav
# File: 06-HF-Mi2.wav
# Sample Rate: 44100 Hz
# Duration: 6.80 seconds
# Channels: 1
# 06-HF-Mi3.wav - First 20 bytes: b'RIFF$L\x12\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\06-HF-Mi3.wav
# File: 06-HF-Mi3.wav
# Sample Rate: 44100 Hz
# Duration: 6.80 seconds
# Channels: 1
# 06-HF-Mi4.wav - First 20 bytes: b'RIFF$L\x12\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\06-HF-Mi4.wav
# File: 06-HF-Mi4.wav
# Sample Rate: 44100 Hz
# Duration: 6.80 seconds
# Channels: 1
# 06-HF-Mi5.wav - First 20 bytes: b'RIFF$L\x12\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\06-HF-Mi5.wav
# File: 06-HF-Mi5.wav
# Sample Rate: 44100 Hz
# Duration: 6.80 seconds
# Channels: 1
# 06-HF-Mi6.wav - First 20 bytes: b'RIFF$L\x12\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\06-HF-Mi6.wav
# File: 06-HF-Mi6.wav
# Sample Rate: 44100 Hz
# Duration: 6.80 seconds
# Channels: 1
# 06-LD-Mi1.wav - First 20 bytes: b'RIFF$t)\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\06-LD-Mi1.wav
# File: 06-LD-Mi1.wav
# Sample Rate: 44100 Hz
# Duration: 15.40 seconds
# Channels: 1
# 06-LD-Mi2.wav - First 20 bytes: b'RIFF$t)\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\06-LD-Mi2.wav
# File: 06-LD-Mi2.wav
# Sample Rate: 44100 Hz
# Duration: 15.40 seconds
# Channels: 1
# 06-LD-Mi3.wav - First 20 bytes: b'RIFF$t)\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\06-LD-Mi3.wav
# File: 06-LD-Mi3.wav
# Sample Rate: 44100 Hz
# Duration: 15.40 seconds
# Channels: 1
# 06-LD-Mi4.wav - First 20 bytes: b'RIFF$t)\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\06-LD-Mi4.wav
# File: 06-LD-Mi4.wav
# Sample Rate: 44100 Hz
# Duration: 15.40 seconds
# Channels: 1
# 06-LD-Mi5.wav - First 20 bytes: b'RIFF$t)\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\06-LD-Mi5.wav
# File: 06-LD-Mi5.wav
# Sample Rate: 44100 Hz
# Duration: 15.40 seconds
# Channels: 1
# 06-LD-Mi6.wav - First 20 bytes: b'RIFF$t)\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\06-LD-Mi6.wav
# File: 06-LD-Mi6.wav
# Sample Rate: 44100 Hz
# Duration: 15.40 seconds
# Channels: 1
# 06-TO-Mi1.wav - First 20 bytes: b'RIFF$d \x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\06-TO-Mi1.wav
# File: 06-TO-Mi1.wav
# Sample Rate: 44100 Hz
# Duration: 12.03 seconds
# Channels: 1
# 06-TO-Mi2.wav - First 20 bytes: b'RIFF$d \x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\06-TO-Mi2.wav
# File: 06-TO-Mi2.wav
# Sample Rate: 44100 Hz
# Duration: 12.03 seconds
# Channels: 1
# 06-TO-Mi3.wav - First 20 bytes: b'RIFF$d \x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\06-TO-Mi3.wav
# File: 06-TO-Mi3.wav
# Sample Rate: 44100 Hz
# Duration: 12.03 seconds
# Channels: 1
# 06-TO-Mi4.wav - First 20 bytes: b'RIFF$d \x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\06-TO-Mi4.wav
# File: 06-TO-Mi4.wav
# Sample Rate: 44100 Hz
# Duration: 12.03 seconds
# Channels: 1
# 06-TO-Mi5.wav - First 20 bytes: b'RIFF$d \x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\06-TO-Mi5.wav
# File: 06-TO-Mi5.wav
# Sample Rate: 44100 Hz
# Duration: 12.03 seconds
# Channels: 1
# 06-TO-Mi6.wav - First 20 bytes: b'RIFF$d \x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\06-TO-Mi6.wav
# File: 06-TO-Mi6.wav
# Sample Rate: 44100 Hz
# Duration: 12.03 seconds
# Channels: 1
# 07-FB-Mi1.wav - First 20 bytes: b'RIFF$\xec\x19\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\07-FB-Mi1.wav
# File: 07-FB-Mi1.wav
# Sample Rate: 44100 Hz
# Duration: 9.63 seconds
# Channels: 1
# 07-FB-Mi2.wav - First 20 bytes: b'RIFF$\xec\x19\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\07-FB-Mi2.wav
# File: 07-FB-Mi2.wav
# Sample Rate: 44100 Hz
# Duration: 9.63 seconds
# Channels: 1
# 07-FB-Mi3.wav - First 20 bytes: b'RIFF$\xec\x19\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\07-FB-Mi3.wav
# File: 07-FB-Mi3.wav
# Sample Rate: 44100 Hz
# Duration: 9.63 seconds
# Channels: 1
# 07-FB-Mi4.wav - First 20 bytes: b'RIFF$\xec\x19\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\07-FB-Mi4.wav
# File: 07-FB-Mi4.wav
# Sample Rate: 44100 Hz
# Duration: 9.63 seconds
# Channels: 1
# 07-FB-Mi5.wav - First 20 bytes: b'RIFF$\xec\x19\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\07-FB-Mi5.wav
# File: 07-FB-Mi5.wav
# Sample Rate: 44100 Hz
# Duration: 9.63 seconds
# Channels: 1
# 07-FB-Mi6.wav - First 20 bytes: b'RIFF$\xec\x19\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\07-FB-Mi6.wav
# ...
# Sample Rate: 44100 Hz
# Duration: 10.72 seconds
# Channels: 1
# 17-TO-Mi6.wav - First 20 bytes: b'RIFF$\xd8\x1c\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\17-TO-Mi6.wav
# File: 17-TO-Mi6.wav
# Sample Rate: 44100 Hz
# Duration: 10.72 seconds
# Channels: 1
# 18-FB-Mi1.wav - First 20 bytes: b'RIFF$p*\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\18-FB-Mi1.wav
# File: 18-FB-Mi1.wav
# Sample Rate: 44100 Hz
# Duration: 15.77 seconds
# Channels: 1
# 18-FB-Mi2.wav - First 20 bytes: b'RIFF$p*\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\18-FB-Mi2.wav
# File: 18-FB-Mi2.wav
# Sample Rate: 44100 Hz
# Duration: 15.77 seconds
# Channels: 1
# 18-FB-Mi3.wav - First 20 bytes: b'RIFF$p*\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\18-FB-Mi3.wav
# File: 18-FB-Mi3.wav
# Sample Rate: 44100 Hz
# Duration: 15.77 seconds
# Channels: 1
# 18-FB-Mi4.wav - First 20 bytes: b'RIFF$p*\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\18-FB-Mi4.wav
# File: 18-FB-Mi4.wav
# Sample Rate: 44100 Hz
# Duration: 15.77 seconds
# Channels: 1
# 18-FB-Mi5.wav - First 20 bytes: b'RIFF$p*\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\18-FB-Mi5.wav
# File: 18-FB-Mi5.wav
# Sample Rate: 44100 Hz
# Duration: 15.77 seconds
# Channels: 1
# 18-FB-Mi6.wav - First 20 bytes: b'RIFF$p*\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\18-FB-Mi6.wav
# File: 18-FB-Mi6.wav
# Sample Rate: 44100 Hz
# Duration: 15.77 seconds
# Channels: 1
# 18-FF-Mi1.wav - First 20 bytes: b'RIFF$\xc8\x1d\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\18-FF-Mi1.wav
# File: 18-FF-Mi1.wav
# Sample Rate: 44100 Hz
# Duration: 11.06 seconds
# Channels: 1
# 18-FF-Mi2.wav - First 20 bytes: b'RIFF$\xc8\x1d\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\18-FF-Mi2.wav
# File: 18-FF-Mi2.wav
# Sample Rate: 44100 Hz
# Duration: 11.06 seconds
# Channels: 1
# 18-FF-Mi3.wav - First 20 bytes: b'RIFF$\xc8\x1d\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\18-FF-Mi3.wav
# File: 18-FF-Mi3.wav
# Sample Rate: 44100 Hz
# Duration: 11.06 seconds
# Channels: 1
# 18-FF-Mi4.wav - First 20 bytes: b'RIFF$\xc8\x1d\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\18-FF-Mi4.wav
# File: 18-FF-Mi4.wav
# Sample Rate: 44100 Hz
# Duration: 11.06 seconds
# Channels: 1
# 18-FF-Mi5.wav - First 20 bytes: b'RIFF$\xc8\x1d\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\18-FF-Mi5.wav
# File: 18-FF-Mi5.wav
# Sample Rate: 44100 Hz
# Duration: 11.06 seconds
# Channels: 1
# 18-FF-Mi6.wav - First 20 bytes: b'RIFF$\xc8\x1d\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\18-FF-Mi6.wav
# File: 18-FF-Mi6.wav
# Sample Rate: 44100 Hz
# Duration: 11.06 seconds
# Channels: 1
# 18-H1-Mi1.wav - First 20 bytes: b'RIFF$\x94\x15\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\18-H1-Mi1.wav
# File: 18-H1-Mi1.wav
# Sample Rate: 44100 Hz
# Duration: 8.02 seconds
# Channels: 1
# 18-H1-Mi2.wav - First 20 bytes: b'RIFF$\x94\x15\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\18-H1-Mi2.wav
# File: 18-H1-Mi2.wav
# Sample Rate: 44100 Hz
# Duration: 8.02 seconds
# Channels: 1
# 18-H1-Mi3.wav - First 20 bytes: b'RIFF$\x94\x15\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\18-H1-Mi3.wav
# File: 18-H1-Mi3.wav
# Sample Rate: 44100 Hz
# Duration: 8.02 seconds
# Channels: 1
# 18-H1-Mi4.wav - First 20 bytes: b'RIFF$\x94\x15\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\18-H1-Mi4.wav
# File: 18-H1-Mi4.wav
# Sample Rate: 44100 Hz
# Duration: 8.02 seconds
# Channels: 1
# 18-H1-Mi5.wav - First 20 bytes: b'RIFF$\x94\x15\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\18-H1-Mi5.wav
# File: 18-H1-Mi5.wav
# Sample Rate: 44100 Hz
# Duration: 8.02 seconds
# Channels: 1
# 18-H1-Mi6.wav - First 20 bytes: b'RIFF$\x94\x15\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\18-H1-Mi6.wav
# File: 18-H1-Mi6.wav
# Sample Rate: 44100 Hz
# Duration: 8.02 seconds
# Channels: 1
# 18-H2-Mi1.wav - First 20 bytes: b'RIFF$\xac\x14\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\18-H2-Mi1.wav
# File: 18-H2-Mi1.wav
# Sample Rate: 44100 Hz
# Duration: 7.68 seconds
# Channels: 1
# 18-H2-Mi2.wav - First 20 bytes: b'RIFF$\xac\x14\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\18-H2-Mi2.wav
# File: 18-H2-Mi2.wav
# Sample Rate: 44100 Hz
# Duration: 7.68 seconds
# Channels: 1
# 18-H2-Mi3.wav - First 20 bytes: b'RIFF$\xac\x14\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\18-H2-Mi3.wav
# File: 18-H2-Mi3.wav
# Sample Rate: 44100 Hz
# Duration: 7.68 seconds
# Channels: 1
# 18-H2-Mi4.wav - First 20 bytes: b'RIFF$\xac\x14\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\18-H2-Mi4.wav
# File: 18-H2-Mi4.wav
# Sample Rate: 44100 Hz
# Duration: 7.68 seconds
# Channels: 1
# 18-H2-Mi5.wav - First 20 bytes: b'RIFF$\xac\x14\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\18-H2-Mi5.wav
# File: 18-H2-Mi5.wav
# Sample Rate: 44100 Hz
# Duration: 7.68 seconds
# Channels: 1
# 18-H2-Mi6.wav - First 20 bytes: b'RIFF$\xac\x14\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\18-H2-Mi6.wav
# File: 18-H2-Mi6.wav
# Sample Rate: 44100 Hz
# Duration: 7.68 seconds
# Channels: 1
# 18-HF-Mi1.wav - First 20 bytes: b'RIFF$\xe0\x13\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\18-HF-Mi1.wav
# File: 18-HF-Mi1.wav
# Sample Rate: 44100 Hz
# Duration: 7.38 seconds
# Channels: 1
# 18-HF-Mi2.wav - First 20 bytes: b'RIFF$\xe0\x13\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\18-HF-Mi2.wav
# File: 18-HF-Mi2.wav
# Sample Rate: 44100 Hz
# Duration: 7.38 seconds
# Channels: 1
# 18-HF-Mi3.wav - First 20 bytes: b'RIFF$\xe0\x13\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\18-HF-Mi3.wav
# File: 18-HF-Mi3.wav
# Sample Rate: 44100 Hz
# Duration: 7.38 seconds
# Channels: 1
# 18-HF-Mi4.wav - First 20 bytes: b'RIFF$\xe0\x13\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\18-HF-Mi4.wav
# File: 18-HF-Mi4.wav
# Sample Rate: 44100 Hz
# Duration: 7.38 seconds
# Channels: 1
# 18-HF-Mi5.wav - First 20 bytes: b'RIFF$\xe0\x13\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\18-HF-Mi5.wav
# File: 18-HF-Mi5.wav
# Sample Rate: 44100 Hz
# Duration: 7.38 seconds
# Channels: 1
# 18-HF-Mi6.wav - First 20 bytes: b'RIFF$\xe0\x13\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\18-HF-Mi6.wav
# File: 18-HF-Mi6.wav
# Sample Rate: 44100 Hz
# Duration: 7.38 seconds
# Channels: 1
# 18-LD-Mi1.wav - First 20 bytes: b'RIFF$h\x1c\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\18-LD-Mi1.wav
# File: 18-LD-Mi1.wav
# Sample Rate: 44100 Hz
# Duration: 10.55 seconds
# Channels: 1
# 18-LD-Mi2.wav - First 20 bytes: b'RIFF$h\x1c\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\18-LD-Mi2.wav
# File: 18-LD-Mi2.wav
# Sample Rate: 44100 Hz
# Duration: 10.55 seconds
# Channels: 1
# 18-LD-Mi3.wav - First 20 bytes: b'RIFF$h\x1c\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\18-LD-Mi3.wav
# File: 18-LD-Mi3.wav
# Sample Rate: 44100 Hz
# Duration: 10.55 seconds
# Channels: 1
# 18-LD-Mi4.wav - First 20 bytes: b'RIFF$h\x1c\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\18-LD-Mi4.wav
# File: 18-LD-Mi4.wav
# Sample Rate: 44100 Hz
# Duration: 10.55 seconds
# Channels: 1
# 18-LD-Mi5.wav - First 20 bytes: b'RIFF$h\x1c\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\18-LD-Mi5.wav
# File: 18-LD-Mi5.wav
# Sample Rate: 44100 Hz
# Duration: 10.55 seconds
# Channels: 1
# 18-LD-Mi6.wav - First 20 bytes: b'RIFF$h\x1c\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\18-LD-Mi6.wav
# File: 18-LD-Mi6.wav
# Sample Rate: 44100 Hz
# Duration: 10.55 seconds
# Channels: 1
# 18-TO-Mi1.wav - First 20 bytes: b'RIFF$\xfc\x1f\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\18-TO-Mi1.wav
# File: 18-TO-Mi1.wav
# Sample Rate: 44100 Hz
# Duration: 11.88 seconds
# Channels: 1
# 18-TO-Mi2.wav - First 20 bytes: b'RIFF$\xfc\x1f\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\18-TO-Mi2.wav
# File: 18-TO-Mi2.wav
# Sample Rate: 44100 Hz
# Duration: 11.88 seconds
# Channels: 1
# 18-TO-Mi3.wav - First 20 bytes: b'RIFF$\xfc\x1f\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\18-TO-Mi3.wav
# File: 18-TO-Mi3.wav
# Sample Rate: 44100 Hz
# Duration: 11.88 seconds
# Channels: 1
# 18-TO-Mi4.wav - First 20 bytes: b'RIFF$\xfc\x1f\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\18-TO-Mi4.wav
# File: 18-TO-Mi4.wav
# Sample Rate: 44100 Hz
# Duration: 11.88 seconds
# Channels: 1
# 18-TO-Mi5.wav - First 20 bytes: b'RIFF$\xfc\x1f\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\18-TO-Mi5.wav
# File: 18-TO-Mi5.wav
# Sample Rate: 44100 Hz
# Duration: 11.88 seconds
# Channels: 1
# 18-TO-Mi6.wav - First 20 bytes: b'RIFF$\xfc\x1f\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\18-TO-Mi6.wav
# File: 18-TO-Mi6.wav
# Sample Rate: 44100 Hz
# Duration: 11.88 seconds
# Channels: 1
# 19-FB-Mi1.wav - First 20 bytes: b'RIFF$\x80\x18\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\19-FB-Mi1.wav
# File: 19-FB-Mi1.wav
# Sample Rate: 44100 Hz
# Duration: 9.10 seconds
# Channels: 1
# 19-FB-Mi2.wav - First 20 bytes: b'RIFF$\x80\x18\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\19-FB-Mi2.wav
# File: 19-FB-Mi2.wav
# Sample Rate: 44100 Hz
# Duration: 9.10 seconds
# Channels: 1
# 19-FB-Mi3.wav - First 20 bytes: b'RIFF$\x80\x18\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\19-FB-Mi3.wav
# File: 19-FB-Mi3.wav
# Sample Rate: 44100 Hz
# Duration: 9.10 seconds
# Channels: 1
# 19-FB-Mi4.wav - First 20 bytes: b'RIFF$\x80\x18\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\19-FB-Mi4.wav
# File: 19-FB-Mi4.wav
# Sample Rate: 44100 Hz
# Duration: 9.10 seconds
# Channels: 1
# 19-FB-Mi5.wav - First 20 bytes: b'RIFF$\x80\x18\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\19-FB-Mi5.wav
# File: 19-FB-Mi5.wav
# Sample Rate: 44100 Hz
# Duration: 9.10 seconds
# Channels: 1
# 19-FB-Mi6.wav - First 20 bytes: b'RIFF$\x80\x18\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\19-FB-Mi6.wav
# File: 19-FB-Mi6.wav
# Sample Rate: 44100 Hz
# Duration: 9.10 seconds
# Channels: 1
# 19-FF-Mi1.wav - First 20 bytes: b'RIFF$\x1c\x17\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\19-FF-Mi1.wav
# File: 19-FF-Mi1.wav
# Sample Rate: 44100 Hz
# Duration: 8.59 seconds
# Channels: 1
# 19-FF-Mi2.wav - First 20 bytes: b'RIFF$\x1c\x17\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\19-FF-Mi2.wav
# File: 19-FF-Mi2.wav
# Sample Rate: 44100 Hz
# Duration: 8.59 seconds
# Channels: 1
# 19-FF-Mi3.wav - First 20 bytes: b'RIFF$\x1c\x17\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\19-FF-Mi3.wav
# File: 19-FF-Mi3.wav
# Sample Rate: 44100 Hz
# Duration: 8.59 seconds
# Channels: 1
# 19-FF-Mi4.wav - First 20 bytes: b'RIFF$\x1c\x17\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\19-FF-Mi4.wav
# File: 19-FF-Mi4.wav
# Sample Rate: 44100 Hz
# Duration: 8.59 seconds
# Channels: 1
# 19-FF-Mi5.wav - First 20 bytes: b'RIFF$\x1c\x17\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\19-FF-Mi5.wav
# File: 19-FF-Mi5.wav
# Sample Rate: 44100 Hz
# Duration: 8.59 seconds
# Channels: 1
# 19-FF-Mi6.wav - First 20 bytes: b'RIFF$\x1c\x17\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\19-FF-Mi6.wav
# File: 19-FF-Mi6.wav
# Sample Rate: 44100 Hz
# Duration: 8.59 seconds
# Channels: 1
# 19-H1-Mi1.wav - First 20 bytes: b'RIFF$\xf8\x16\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\19-H1-Mi1.wav
# File: 19-H1-Mi1.wav
# Sample Rate: 44100 Hz
# Duration: 8.53 seconds
# Channels: 1
# 19-H1-Mi2.wav - First 20 bytes: b'RIFF$\xf8\x16\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\19-H1-Mi2.wav
# File: 19-H1-Mi2.wav
# Sample Rate: 44100 Hz
# Duration: 8.53 seconds
# Channels: 1
# 19-H1-Mi3.wav - First 20 bytes: b'RIFF$\xf8\x16\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\19-H1-Mi3.wav
# File: 19-H1-Mi3.wav
# Sample Rate: 44100 Hz
# Duration: 8.53 seconds
# Channels: 1
# 19-H1-Mi4.wav - First 20 bytes: b'RIFF$\xf8\x16\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\19-H1-Mi4.wav
# File: 19-H1-Mi4.wav
# Sample Rate: 44100 Hz
# Duration: 8.53 seconds
# Channels: 1
# 19-H1-Mi5.wav - First 20 bytes: b'RIFF$\xf8\x16\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\19-H1-Mi5.wav
# File: 19-H1-Mi5.wav
# Sample Rate: 44100 Hz
# Duration: 8.53 seconds
# Channels: 1
# 19-H1-Mi6.wav - First 20 bytes: b'RIFF$\xf8\x16\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\19-H1-Mi6.wav
# File: 19-H1-Mi6.wav
# Sample Rate: 44100 Hz
# Duration: 8.53 seconds
# Channels: 1
# 19-H2-Mi1.wav - First 20 bytes: b'RIFF$h\x18\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\19-H2-Mi1.wav
# File: 19-H2-Mi1.wav
# Sample Rate: 44100 Hz
# Duration: 9.07 seconds
# Channels: 1
# 19-H2-Mi2.wav - First 20 bytes: b'RIFF$h\x18\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\19-H2-Mi2.wav
# File: 19-H2-Mi2.wav
# Sample Rate: 44100 Hz
# Duration: 9.07 seconds
# Channels: 1
# 19-H2-Mi3.wav - First 20 bytes: b'RIFF$h\x18\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\19-H2-Mi3.wav
# File: 19-H2-Mi3.wav
# Sample Rate: 44100 Hz
# Duration: 9.07 seconds
# Channels: 1
# 19-H2-Mi4.wav - First 20 bytes: b'RIFF$h\x18\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\19-H2-Mi4.wav
# File: 19-H2-Mi4.wav
# Sample Rate: 44100 Hz
# Duration: 9.07 seconds
# Channels: 1
# 19-H2-Mi5.wav - First 20 bytes: b'RIFF$h\x18\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\19-H2-Mi5.wav
# File: 19-H2-Mi5.wav
# Sample Rate: 44100 Hz
# Duration: 9.07 seconds
# Channels: 1
# 19-H2-Mi6.wav - First 20 bytes: b'RIFF$h\x18\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\19-H2-Mi6.wav
# File: 19-H2-Mi6.wav
# Sample Rate: 44100 Hz
# Duration: 9.07 seconds
# Channels: 1
# 19-HF-Mi1.wav - First 20 bytes: b'RIFF$\xf8\x13\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\19-HF-Mi1.wav
# File: 19-HF-Mi1.wav
# Sample Rate: 44100 Hz
# Duration: 7.42 seconds
# Channels: 1
# 19-HF-Mi2.wav - First 20 bytes: b'RIFF$\xf8\x13\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\19-HF-Mi2.wav
# File: 19-HF-Mi2.wav
# Sample Rate: 44100 Hz
# Duration: 7.42 seconds
# Channels: 1
# 19-HF-Mi3.wav - First 20 bytes: b'RIFF$\xf8\x13\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\19-HF-Mi3.wav
# File: 19-HF-Mi3.wav
# Sample Rate: 44100 Hz
# Duration: 7.42 seconds
# Channels: 1
# 19-HF-Mi4.wav - First 20 bytes: b'RIFF$\xf8\x13\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\19-HF-Mi4.wav
# File: 19-HF-Mi4.wav
# Sample Rate: 44100 Hz
# Duration: 7.42 seconds
# Channels: 1
# 19-HF-Mi5.wav - First 20 bytes: b'RIFF$\xf8\x13\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\19-HF-Mi5.wav
# File: 19-HF-Mi5.wav
# Sample Rate: 44100 Hz
# Duration: 7.42 seconds
# Channels: 1
# 19-HF-Mi6.wav - First 20 bytes: b'RIFF$\xf8\x13\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\19-HF-Mi6.wav
# File: 19-HF-Mi6.wav
# Sample Rate: 44100 Hz
# Duration: 7.42 seconds
# Channels: 1
# 19-LD-Mi1.wav - First 20 bytes: b"RIFF$\xf8'\x00WAVEfmt \x10\x00\x00\x00"
# Saved: D:/audioswav\19-LD-Mi1.wav
# File: 19-LD-Mi1.wav
# Sample Rate: 44100 Hz
# Duration: 14.85 seconds
# Channels: 1
# 19-LD-Mi2.wav - First 20 bytes: b"RIFF$\xf8'\x00WAVEfmt \x10\x00\x00\x00"
# Saved: D:/audioswav\19-LD-Mi2.wav
# File: 19-LD-Mi2.wav
# Sample Rate: 44100 Hz
# Duration: 14.85 seconds
# Channels: 1
# 19-LD-Mi3.wav - First 20 bytes: b"RIFF$\xf8'\x00WAVEfmt \x10\x00\x00\x00"
# Saved: D:/audioswav\19-LD-Mi3.wav
# File: 19-LD-Mi3.wav
# Sample Rate: 44100 Hz
# Duration: 14.85 seconds
# Channels: 1
# 19-LD-Mi4.wav - First 20 bytes: b"RIFF$\xf8'\x00WAVEfmt \x10\x00\x00\x00"
# Saved: D:/audioswav\19-LD-Mi4.wav
# File: 19-LD-Mi4.wav
# Sample Rate: 44100 Hz
# Duration: 14.85 seconds
# Channels: 1
# 19-LD-Mi5.wav - First 20 bytes: b"RIFF$\xf8'\x00WAVEfmt \x10\x00\x00\x00"
# Saved: D:/audioswav\19-LD-Mi5.wav
# File: 19-LD-Mi5.wav
# Sample Rate: 44100 Hz
# Duration: 14.85 seconds
# Channels: 1
# 19-LD-Mi6.wav - First 20 bytes: b"RIFF$\xf8'\x00WAVEfmt \x10\x00\x00\x00"
# Saved: D:/audioswav\19-LD-Mi6.wav
# File: 19-LD-Mi6.wav
# Sample Rate: 44100 Hz
# Duration: 14.85 seconds
# Channels: 1
# 19-TO-Mi1.wav - First 20 bytes: b'RIFF$p\x19\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\19-TO-Mi1.wav
# File: 19-TO-Mi1.wav
# Sample Rate: 44100 Hz
# Duration: 9.45 seconds
# Channels: 1
# 19-TO-Mi2.wav - First 20 bytes: b'RIFF$p\x19\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\19-TO-Mi2.wav
# File: 19-TO-Mi2.wav
# Sample Rate: 44100 Hz
# Duration: 9.45 seconds
# Channels: 1
# 19-TO-Mi3.wav - First 20 bytes: b'RIFF$p\x19\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\19-TO-Mi3.wav
# File: 19-TO-Mi3.wav
# Sample Rate: 44100 Hz
# Duration: 9.45 seconds
# Channels: 1
# 19-TO-Mi4.wav - First 20 bytes: b'RIFF$p\x19\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\19-TO-Mi4.wav
# File: 19-TO-Mi4.wav
# Sample Rate: 44100 Hz
# Duration: 9.45 seconds
# Channels: 1
# 19-TO-Mi5.wav - First 20 bytes: b'RIFF$p\x19\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\19-TO-Mi5.wav
# File: 19-TO-Mi5.wav
# Sample Rate: 44100 Hz
# Duration: 9.45 seconds
# Channels: 1
# 19-TO-Mi6.wav - First 20 bytes: b'RIFF$p\x19\x00WAVEfmt \x10\x00\x00\x00'
# Saved: D:/audioswav\19-TO-Mi6.wav
# File: 19-TO-Mi6.wav
# Sample Rate: 44100 Hz
# Duration: 9.45 seconds
# Channels: 1
# Conversion complete!
